# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\mahe\Desktop\Task 3\supermarket_sales - Sheet1.csv')

# %%
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
data['Date'] = pd.to_datetime(data['Date'])

# %%
data['day'] = (data['Date']).dt.day
data['month'] = (data['Date']).dt.month
data['year'] = (data['Date']).dt.year

# %%
data.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                               object
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# day                                 int64
# month                               int64
# year                                int64
# dtype: object

# %%
data['Time'] = pd.to_datetime(data['Time'])

# %%
data['Hour'] = (data['Time']).dt.hour

# %%
import seaborn as sns
sns.set(style="darkgrid")       
genderCount  = sns.countplot(x="Gender", data =data).set_title("Gender_Count")

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating', 'day', 'month', 'year', 'Hour'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Invoice ID                         object
# Branch                             object
# City                               object
# Customer type                      object
# Gender                             object
# Product line                       object
# Unit price                        float64
# Quantity                            int64
# Tax 5%                            float64
# Total                             float64
# Date                       datetime64[ns]
# Time                       datetime64[ns]
# Payment                            object
# cogs                              float64
# gross margin percentage           float64
# gross income                      float64
# Rating                            float64
# day                                 int64
# month                               int64
# year                                int64
# Hour                                int64
# dtype: object

# %%
df = data.drop(['Invoice ID', 'Date','Time'],axis =1)

# %%
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total      Payment    cogs  \
# 0         74.69         7  26.1415   548.9715      Ewallet  522.83
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['Branch'] = le.fit_transform(data['Branch'])
data['City'] = le.fit_transform(data['City'])
data['Customer type'] = le.fit_transform(data['Customer type'])
data['Gender'] = le.fit_transform(data['Gender'])
data['Product line'] = le.fit_transform(data['Product line'])
data['Payment'] = le.fit_transform(data['Payment'])

# %%
df = data.drop(['Invoice ID', 'Date','Time'],axis =1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale
X= df.drop('Rating',axis =1)
X =scale(X)
Y = df['Rating']
X_train,x_test,Y_train,y_test = train_test_split(X,Y,test_size = 0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression()
linear_model.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
linear_model.score(X_train,Y_train)
# Out:
# 0.017099168185307434

# %%
import xgboost as xgb

# %%
reg = xgb.XGBRegressor(n_estimators=1000)

# %%
reg.fit(X_train, Y_train,
        eval_set=[(X_train, Y_train), (x_test, y_test)],
        early_stopping_rounds=50,
       verbose=False)
# Out:
# XGBRegressor(base_score=0.5, booster=None, colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints=None,
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method=None,
#              validate_parameters=False, verbosity=None)

# %%
reg.score(X_train,Y_train)
# Out:
# 0.2684529924618454

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model = RandomForestRegressor(n_estimators=200,max_depth=25, min_samples_leaf=60,n_jobs=4)
rf_model.fit(X_train,Y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=25, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=60,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=200, n_jobs=4, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
rf_model.score(X_train,Y_train)
# Out:
# 0.054326466869614176

# %%
from sklearn.svm import SVR
svr_model = SVR(kernel = 'rbf',C=100)
svr_model.fit(X_train, Y_train)
# Out:
# SVR(C=100, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
svr_model.score(X_train,Y_train)
# Out:
# 0.9282079746746213

# %%
y_pred = svr_model.predict(x_test)

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = {15,30}

plt.plot(y_pred,label = 'Predicted')
plt.plot(y_test.values,label = 'Actual')
plt.ylabel('Rating')

plt.legend()
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 6.286119249976659

# %%
y_pred_all = svr_model.predict(X)

# %%
df['Predicted Rating'] = y_pred_all

# %%
df
# Out:
#      Branch  City  Customer type  Gender  Product line  Unit price  Quantity  \
# 0         0     2              0       0             3       74.69         7
# 1         2     1              1       0             0       15.28         5
# 2         0     2              1       1             4       46.33         7
# 3         0     2              0       1             3       58.22         8
# 4         0     2              1       1             5       86.31         7
# ..      ...   ...            ...     ...           ...         ...       ...
# 995       2     1              1       1             3       40.35         1
# 996       1     0              1       0             4       97.38        10
# 997       0     2              0       1             2       31.84         1
# 998       0     2              1       1             4       65.82         1
# 999       0     2              0       0             1       88.34         7
#
# ...

# %%
df.to_csv(r'C:\Users\mahe\Desktop\Task 3\rating_pred.csv',index= False)

# %%
df2 = data.drop(['Invoice ID', 'Branch', 'Customer type', 'Gender',
       'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
       'Time', 'Payment', 'cogs', 'gross margin percentage',
       'Rating', 'day', 'month', 'year', 'Hour'],axis=1)

# %%
df2
# Out:
#      City  gross income
# 0       2       26.1415
# 1       1        3.8200
# 2       2       16.2155
# 3       2       23.2880
# 4       2       30.2085
# ..    ...           ...
# 995     1        2.0175
# 996     0       48.6900
# 997     2        1.5920
# 998     2        3.2910
# 999     2       30.9190
#
# [1000 rows x 2 columns]

# %%
city_grossincome_corr = df2.corr()
city_grossincome_corr
# Out:
#                   City  gross income
# City          1.000000     -0.012812
# gross income -0.012812      1.000000

# %%
df2.to_csv(r'C:\Users\mahe\Desktop\Task 3\corr.csv',index= False)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig,ax = plt.subplots(figsize = (20,10))
sns.heatmap(city_grossincome_corr,annot = True)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
def naive_bayes(x_train,y_train):
    classifier = GaussianNB()
    classifier.fit(x_train,y_train)
    
    return classifier

# %%
def k_nearest_neighbors(x_train,y_train):
    classifier = KNeighborsClassifier(n_neighbors=10)
    classifier.fit(x_train,y_train)
    
    return classifier

# %%
def svc(x_train,y_train):
    classifier = SVC(kernel = 'rbf', gamma = 'scale')
    classifier.fit(x_train,y_train)
    
    return classifier

# %%
def decision_tree(x_train,y_train):
    classifier = DecisionTreeClassifier(max_depth=6)
    classifier.fit(x_train,y_train)
    
    return classifier

# %%
from sklearn.metrics import accuracy_score

# %%
def build_and_train_classifier(x_train,y_train,classification_fn):
    model = classification_fn(x_train,y_train)
    y_pred = model.predict(x_test)
    
    train_score = model.score(x_train,y_train)
    test_score = accuracy = accuracy_score(y_test,y_pred)
    
    print("Training Score: ",train_score)
    print("Testing Score: ", test_score)

# %%
df3 = data.drop(['Invoice ID', 'Date','Time'],axis =1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale
X= df3.drop('Gender',axis =1)
X =scale(X)
Y = df3['Gender']
X_train,x_test,Y_train,y_test = train_test_split(X,Y,test_size = 0.2,random_state=0)

# %%
Y2
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 995    1
# 996    0
# 997    1
# 998    1
# 999    0
# Name: Gender, Length: 1000, dtype: int32

# %%
build_and_train_classifier(X_train,Y_train,naive_bayes)
# Out:
# Training Score:  0.54125
# Testing Score:  0.505

# %%
build_and_train_classifier(X_train,Y_train,k_nearest_neighbors)
# Out:
# Training Score:  0.64625
# Testing Score:  0.565

# %%
build_and_train_classifier(X_train,Y_train,svc)
# Out:
# Training Score:  0.72125
# Testing Score:  0.565

# %%
build_and_train_classifier(X_train,Y_train,decision_tree)
# Out:
# Training Score:  0.665
# Testing Score:  0.5

# %%
svc_model = SVC(kernel = 'rbf', gamma = 'scale')

# %%
svc_model.fit(X_train,Y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
accuracy_score(Y,y_pred_all_svc)
# Out:
# 0.69

# %%
df3['Predicted Gender'] = y_pred_all_svc

# %%
df3
# Out:
#      Branch  City  Customer type  Gender  Product line  Unit price  Quantity  \
# 0         0     2              0       0             3       74.69         7
# 1         2     1              1       0             0       15.28         5
# 2         0     2              1       1             4       46.33         7
# 3         0     2              0       1             3       58.22         8
# 4         0     2              1       1             5       86.31         7
# ..      ...   ...            ...     ...           ...         ...       ...
# 995       2     1              1       1             3       40.35         1
# 996       1     0              1       0             4       97.38        10
# 997       0     2              0       1             2       31.84         1
# 998       0     2              1       1             4       65.82         1
# 999       0     2              0       0             1       88.34         7
#
# ...

# %%
df3.to_csv(r'C:\Users\mahe\Desktop\Task 3\gender_pred.csv',index= False)

# %%
df5 = data.drop(['Invoice ID', 'Date','Time'],axis =1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale
X= df5.drop('Customer type',axis =1)
X =scale(X)
Y = df5['Customer type']
X_train,x_test,Y_train,y_test = train_test_split(X,Y,test_size = 0.2,random_state=0)

# %%
build_and_train_classifier(X_train,Y_train,naive_bayes)
# Out:
# Training Score:  0.54625
# Testing Score:  0.49

# %%
build_and_train_classifier(X_train,Y_train,k_nearest_neighbors)
# Out:
# Training Score:  0.61625
# Testing Score:  0.52

# %%
build_and_train_classifier(X_train,Y_train,svc)
# Out:
# Training Score:  0.715
# Testing Score:  0.545

# %%
build_and_train_classifier(X_train,Y_train,decision_tree)
# Out:
# Training Score:  0.59125
# Testing Score:  0.49

# %%
svc_model_ctype = SVC(kernel = 'rbf', gamma = 'scale')

# %%
svc_model_ctype.fit(X_train,Y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
y_pred_all_svc_ctype = svc_model_ctype.predict(X)

# %%
accuracy_score(Y,y_pred_all_svc_ctype)
# Out:
# 0.681

# %%
df5['Predicted'] = y_pred_all_svc_ctype

# %%
df5.to_csv(r'C:\Users\mahe\Desktop\Task 3\cust_type_pred.csv',index= False)

# %%
df4.to_csv(r'C:\Users\mahe\Desktop\Task 3\segmented_grossincome.csv',index= False)

# %%
df3
# Out:
#      Branch  City  Customer type  Gender  Product line  Unit price  Quantity  \
# 0         0     2              0       0             3       74.69         7
# 1         2     1              1       0             0       15.28         5
# 2         0     2              1       1             4       46.33         7
# 3         0     2              0       1             3       58.22         8
# 4         0     2              1       1             5       86.31         7
# ..      ...   ...            ...     ...           ...         ...       ...
# 995       2     1              1       1             3       40.35         1
# 996       1     0              1       0             4       97.38        10
# 997       0     2              0       1             2       31.84         1
# 998       0     2              1       1             4       65.82         1
# 999       0     2              0       0             1       88.34         7
#
# ...

# %%
df4 = data.drop(['Invoice ID', 'City', 'Customer type', 'Gender',
       'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
       'Time', 'Payment', 'cogs', 'gross margin percentage',
       'Rating', 'day', 'month', 'year', 'Hour'],axis =1)

# %%
df4
# Out:
#      Branch  gross income
# 0         0       26.1415
# 1         2        3.8200
# 2         0       16.2155
# 3         0       23.2880
# 4         0       30.2085
# ..      ...           ...
# 995       2        2.0175
# 996       1       48.6900
# 997       0        1.5920
# 998       0        3.2910
# 999       0       30.9190
#
# [1000 rows x 2 columns]

# %%
df4.groupby(['Branch']).mean()
# Out:
#         gross income
# Branch
# 0          14.874001
# 1          15.232024
# 2          16.052367
