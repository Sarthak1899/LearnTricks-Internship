# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\mahe\Desktop\Internship\Task 5\Bank Deposite.csv')

# %%
data.head(10)
# Out:
#       Institution Name  Main Office                           Branch Name  \
# 0  JPMorgan Chase Bank            1       JPMorgan Chase Bank Main Office
# 1  JPMorgan Chase Bank            0         Vernon Hills Scarsdale Branch
# 2  JPMorgan Chase Bank            0  Great Neck Northern Boulevard Branch
# 3  JPMorgan Chase Bank            0                North Hartsdale Branch
# 4  JPMorgan Chase Bank            0              Lawrence Rockaway Branch
# 5  JPMorgan Chase Bank            0                   Mount Vernon Branch
# 6  JPMorgan Chase Bank            0                    Castle Hill Branch
# 7  JPMorgan Chase Bank            0                Burnside Avenue Branch
# 8  JPMorgan Chase Bank            0                       Gun Hill Branch
# 9  JPMorgan Chase Bank            0               Kingsbridge Road Branch
#
#    Branch Number Established Date Acquired Date            Street Address  \
# 0              0       01/01/1824           NaN      1111 Polaris Parkway
# ...

# %%
data['Acquired Date'].value_counts()
# Out:
# 11/13/2004    1602
# 09/25/2008    1528
# 10-01-2006     238
# 07/14/1996     157
# 08-01-2000     122
# 06/20/1992      69
# 12-01-1996      27
# 01/18/1975      26
# 08/16/2008      15
# 04-01-1977       3
# 11-10-1975       3
# 03/13/1992       2
# 11-10-2001       1
# 11-08-1991       1
# 11-09-1990       1
# 10/26/1981       1
# 07/19/1991       1
# Name: Acquired Date, dtype: int64

# %%
data['Institution Name'].value_counts()
# Out:
# JPMorgan Chase Bank    4674
# Name: Institution Name, dtype: int64

# %%
data['Branch Name'].value_counts()
# Out:
# Riverside Branch               4
# Westwood Branch                4
# Drive-In Facility Branch       4
# Oceanside Branch               3
# Lakewood Branch                3
#                               ..
# Lbj and Abrams Branch          1
# Baton Rouge Drive-Up Branch    1
# Tippecanoe Mall Branch         1
# Federal Branch                 1
# Dobson Ranch Branch            1
# Name: Branch Name, Length: 4579, dtype: int64

# %%
data['City'].value_counts()
# Out:
# New York City        148
# Houston              130
# Chicago              105
# Brooklyn              74
# Dallas                61
#                     ...
# Suisun City            1
# Choctaw                1
# Crowley                1
# Monmouth Junction      1
# Woodmere               1
# Name: City, Length: 1750, dtype: int64

# %%
data.describe()
# Out:
#        Main Office  Branch Number       Zipcode     Latitude    Longitude  \
# count  4674.000000    4674.000000   4674.000000  4660.000000  4660.000000
# mean      0.000214    3785.785195  57946.741977    37.640746   -94.472316
# std       0.014627    1834.040168  30765.007835     5.266145    17.136156
# min       0.000000       0.000000   2110.000000     0.000000  -124.421370
# 25%       0.000000    2327.500000  33327.000000    33.419803  -111.984948
# 50%       0.000000    3734.500000  60621.000000    39.809295   -88.270405
# 75%       0.000000    5227.750000  85282.000000    41.160990   -81.321735
# max       1.000000    7129.000000  99362.000000    48.801330     0.000000
#
#        2010 Deposits  2011 Deposits  2012 Deposits  2013 Deposits  \
# count   4.673000e+03   4.674000e+03   4.674000e+03   4.674000e+03
# mean    2.668657e+05   3.138801e+05   3.506786e+05   3.858744e+05
# std     9.568755e+06   1.129789e+07   1.263326e+07   1.389206e+07
# ...

# %%
data['Branch Number'].value_counts()
# Out:
# 2047    1
# 6738    1
# 2620    1
# 573     1
# 6718    1
#        ..
# 5304    1
# 1210    1
# 3259    1
# 5308    1
# 0       1
# Name: Branch Number, Length: 4674, dtype: int64

# %%
data['Branch Name'].value_counts()
# Out:
# Riverside Branch               4
# Westwood Branch                4
# Drive-In Facility Branch       4
# Oceanside Branch               3
# Lakewood Branch                3
#                               ..
# Lbj and Abrams Branch          1
# Baton Rouge Drive-Up Branch    1
# Tippecanoe Mall Branch         1
# Federal Branch                 1
# Dobson Ranch Branch            1
# Name: Branch Name, Length: 4579, dtype: int64

# %%
data['Main Office'].value_counts()
# Out:
# 0    4673
# 1       1
# Name: Main Office, dtype: int64

# %%
data.drop([0])
# Out:
#          Institution Name  Main Office                           Branch Name  \
# 1     JPMorgan Chase Bank            0         Vernon Hills Scarsdale Branch
# 2     JPMorgan Chase Bank            0  Great Neck Northern Boulevard Branch
# 3     JPMorgan Chase Bank            0                North Hartsdale Branch
# 4     JPMorgan Chase Bank            0              Lawrence Rockaway Branch
# 5     JPMorgan Chase Bank            0                   Mount Vernon Branch
# ...                   ...          ...                                   ...
# 4669  JPMorgan Chase Bank            0                     Euclid Ave Branch
# 4670  JPMorgan Chase Bank            0  North Hollywood Arts District Branch
# 4671  JPMorgan Chase Bank            0                  West Flushing Branch
# 4672  JPMorgan Chase Bank            0                   Elston Plaza Branch
# 4673  JPMorgan Chase Bank            0          Market Place At Brick Branch
#
# ...

# %%
data
# Out:
#          Institution Name  Main Office                           Branch Name  \
# 0     JPMorgan Chase Bank            1       JPMorgan Chase Bank Main Office
# 1     JPMorgan Chase Bank            0         Vernon Hills Scarsdale Branch
# 2     JPMorgan Chase Bank            0  Great Neck Northern Boulevard Branch
# 3     JPMorgan Chase Bank            0                North Hartsdale Branch
# 4     JPMorgan Chase Bank            0              Lawrence Rockaway Branch
# ...                   ...          ...                                   ...
# 4669  JPMorgan Chase Bank            0                     Euclid Ave Branch
# 4670  JPMorgan Chase Bank            0  North Hollywood Arts District Branch
# 4671  JPMorgan Chase Bank            0                  West Flushing Branch
# 4672  JPMorgan Chase Bank            0                   Elston Plaza Branch
# 4673  JPMorgan Chase Bank            0          Market Place At Brick Branch
#
# ...

# %%
df =data.drop([0])

# %%
df.describe()
# Out:
#        Main Office  Branch Number       Zipcode     Latitude    Longitude  \
# count       4673.0    4673.000000   4673.000000  4659.000000  4659.000000
# mean           0.0    3786.595335  57949.889150    37.640209   -94.474780
# std            0.0    1833.399841  30767.547667     5.266583    17.137170
# min            0.0       2.000000   2110.000000     0.000000  -124.421370
# 25%            0.0    2329.000000  33326.000000    33.418815  -111.985365
# 50%            0.0    3735.000000  60622.000000    39.807320   -88.275830
# 75%            0.0    5228.000000  85282.000000    41.161540   -81.320430
# max            0.0    7129.000000  99362.000000    48.801330     0.000000
#
#        2010 Deposits  2011 Deposits  2012 Deposits  2013 Deposits  \
# count   4.672000e+03   4.673000e+03   4.673000e+03   4.673000e+03
# mean    1.314068e+05   1.548914e+05   1.726122e+05   1.898211e+05
# std     2.411818e+06   3.081832e+06   3.376395e+06   3.652137e+06
# ...

# %%
data['City'].value_counts()
# Out:
# New York City        148
# Houston              130
# Chicago              105
# Brooklyn              74
# Dallas                61
#                     ...
# Suisun City            1
# Choctaw                1
# Crowley                1
# Monmouth Junction      1
# Woodmere               1
# Name: City, Length: 1750, dtype: int64

# %%
df = data.groupby(['Branch Name']).sum()

# %%
df.index
# Out:
# Index(['1 30 and Broadway Branch', '112th & Broadway Branch',
#        '12 Mile-Country Club Drive Branch', '12335 Venice Blvd Branch',
#        '135th Street & Fifth Avenue Branch', '1400 NW 17th Avenue Branch',
#        '1600 N. Plano Rd Branch', '187-15 Union Turnpike Branch',
#        '1870 Aloma Branch', '2209 Via Anacapa Branch',
#        ...
#        'Yukon Banking Center Branch', 'Yuma Branch', 'Yuma West Branch',
#        'Yuma and Cotton Branch', 'Zachary Branch', 'Zandale Branch',
#        'Zanesville Brandywine Branch', 'Zanesville Downtown Branch',
#        'Zeeb Road Banking Branch', 'Zionsville Branch'],
#       dtype='object', name='Branch Name', length=4579)

# %%
data
# Out:
#          Institution Name  Main Office                           Branch Name  \
# 0     JPMorgan Chase Bank            1       JPMorgan Chase Bank Main Office
# 1     JPMorgan Chase Bank            0         Vernon Hills Scarsdale Branch
# 2     JPMorgan Chase Bank            0  Great Neck Northern Boulevard Branch
# 3     JPMorgan Chase Bank            0                North Hartsdale Branch
# 4     JPMorgan Chase Bank            0              Lawrence Rockaway Branch
# ...                   ...          ...                                   ...
# 4669  JPMorgan Chase Bank            0                     Euclid Ave Branch
# 4670  JPMorgan Chase Bank            0  North Hollywood Arts District Branch
# 4671  JPMorgan Chase Bank            0                  West Flushing Branch
# 4672  JPMorgan Chase Bank            0                   Elston Plaza Branch
# 4673  JPMorgan Chase Bank            0          Market Place At Brick Branch
#
# ...

# %%
df.describe()
# Out:
#        Main Office  Branch Number        Zipcode     Latitude    Longitude  \
# count  4579.000000    4579.000000    4579.000000  4579.000000  4579.000000
# mean      0.000218    3864.328456   59148.956541    38.306590   -96.143479
# std       0.014778    1896.502935   32295.407831     8.334419    23.013525
# min       0.000000       0.000000    2110.000000     0.000000  -410.388130
# 25%       0.000000    2391.000000   33431.500000    33.451835  -112.265830
# 50%       0.000000    3799.000000   60639.000000    39.846970   -88.720180
# 75%       0.000000    5296.500000   85344.500000    41.368520   -81.452315
# max       1.000000   15552.000000  311545.000000   152.242100     0.000000
#
#        2010 Deposits  2011 Deposits  2012 Deposits  2013 Deposits  \
# count   4.579000e+03   4.579000e+03   4.579000e+03   4.579000e+03
# mean    2.723440e+05   3.203921e+05   3.579541e+05   3.938801e+05
# std     9.666431e+06   1.141443e+07   1.276357e+07   1.403536e+07
# ...

# %%
df[df['2016 Deposits']==1.155185e+09]
# Out:
#                                  Main Office  Branch Number  Zipcode  \
# Branch Name
# JPMorgan Chase Bank Main Office            1              0    43240
#
#                                  Latitude  Longitude  2010 Deposits  \
# Branch Name
# JPMorgan Chase Bank Main Office  40.14453  -82.99115    633131000.0
#
#                                  2011 Deposits  2012 Deposits  2013 Deposits  \
# Branch Name
# JPMorgan Chase Bank Main Office      743268000      832455000      916543000
#
#                                  2014 Deposits  2015 Deposits  2016 Deposits
# Branch Name
# JPMorgan Chase Bank Main Office     1032549000     1069425000     1155185000

# %%
data.columns
# Out:
# Index(['Institution Name', 'Main Office', 'Branch Name', 'Branch Number',
#        'Established Date', 'Acquired Date', 'Street Address', 'City', 'County',
#        'State', 'Zipcode', 'Latitude', 'Longitude', '2010 Deposits',
#        '2011 Deposits', '2012 Deposits', '2013 Deposits', '2014 Deposits',
#        '2015 Deposits', '2016 Deposits'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Main Office', 'Branch Number', 'Zipcode', 'Latitude', 'Longitude',
#        '2010 Deposits', '2011 Deposits', '2012 Deposits', '2013 Deposits',
#        '2014 Deposits', '2015 Deposits', '2016 Deposits'],
#       dtype='object')

# %%
df.drop(['Main Office', 'Branch Number', 'Zipcode', 'Latitude', 'Longitude'],axis = 1,inplace = True)

# %%
df
# Out:
#                                     2010 Deposits  2011 Deposits  \
# Branch Name
# 1 30 and Broadway Branch                   7231.0          10962
# 112th & Broadway Branch                   31362.0          43147
# 12 Mile-Country Club Drive Branch         87316.0          96703
# 12335 Venice Blvd Branch                 100201.0         112127
# 135th Street & Fifth Avenue Branch        52478.0          54744
# ...                                           ...            ...
# Zandale Branch                            53785.0          56823
# Zanesville Brandywine Branch              31225.0          33938
# Zanesville Downtown Branch                40327.0          49889
# Zeeb Road Banking Branch                  36720.0          44596
# Zionsville Branch                         76667.0          86454
#
#                                     2012 Deposits  2013 Deposits  \
# Branch Name
# 1 30 and Broadway Branch                    14277          18811
# ...

# %%
df_change = df.pct_change(axis='columns')

# %%
df_change.describe()
# Out:
#        2010 Deposits  2011 Deposits  2012 Deposits  2013 Deposits  \
# count            0.0    4453.000000    4452.000000    4450.000000
# mean             NaN            inf       0.164956       0.119472
# std              NaN            NaN       1.186748       0.229547
# min              NaN      -1.000000      -1.000000      -0.991419
# 25%              NaN       0.008255       0.049478       0.037874
# 50%              NaN       0.062006       0.105961       0.090386
# 75%              NaN       0.152214       0.189540       0.163828
# max              NaN            inf      78.217296      11.589462
#
#        2014 Deposits  2015 Deposits  2016 Deposits
# count    4450.000000    4450.000000    4450.000000
# mean        0.108617       0.108432       0.129736
# std         0.223969       0.208064       0.245691
# min        -0.609794      -0.965889      -0.991584
# 25%         0.032860       0.040342       0.058812
# 50%         0.077682       0.083620       0.105780
# ...

# %%
mx = df_change['2016 Deposits'].max()

# %%
df_change[df_change['2016 Deposits']==mx]
# Out:
#                              2010 Deposits  2011 Deposits  2012 Deposits  \
# Branch Name
# Dequindre 18 Mile Rd Branch            NaN       0.269978       0.192449
#
#                              2013 Deposits  2014 Deposits  2015 Deposits  \
# Branch Name
# Dequindre 18 Mile Rd Branch        0.12778       0.149726       0.102304
#
#                              2016 Deposits
# Branch Name
# Dequindre 18 Mile Rd Branch       8.178803

# %%
data[data['Branch Name']== 'Riverside Branch' ]
# Out:
#          Institution Name  Main Office       Branch Name  Branch Number  \
# 492   JPMorgan Chase Bank            0  Riverside Branch           1445
# 2094  JPMorgan Chase Bank            0  Riverside Branch           3428
# 2518  JPMorgan Chase Bank            0  Riverside Branch           3991
# 4286  JPMorgan Chase Bank            0  Riverside Branch           6615
#
#      Established Date Acquired Date                     Street Address  \
# 492        04-06-1994    08-01-2000                        5445 Almeda
# 2094       07-01-2003    11/13/2004          401 North Colonial Street
# 2518       08-09-1973    10-01-2006            1150 East Putnam Avenue
# 4286       07-01-2007    09/25/2008  1299 University Avenue, Suite 105
#
#             City     County State  Zipcode  Latitude  Longitude  \
# 492      Houston     Harris    TX    77004  29.72131  -95.37927
# 2094  Fort Worth    Tarrant    TX    76111  32.77050  -97.29932
# ...

# %%
data['Count']=1

# %%
data
# Out:
#          Institution Name  Main Office                           Branch Name  \
# 0     JPMorgan Chase Bank            1       JPMorgan Chase Bank Main Office
# 1     JPMorgan Chase Bank            0         Vernon Hills Scarsdale Branch
# 2     JPMorgan Chase Bank            0  Great Neck Northern Boulevard Branch
# 3     JPMorgan Chase Bank            0                North Hartsdale Branch
# 4     JPMorgan Chase Bank            0              Lawrence Rockaway Branch
# ...                   ...          ...                                   ...
# 4669  JPMorgan Chase Bank            0                     Euclid Ave Branch
# 4670  JPMorgan Chase Bank            0  North Hollywood Arts District Branch
# 4671  JPMorgan Chase Bank            0                  West Flushing Branch
# 4672  JPMorgan Chase Bank            0                   Elston Plaza Branch
# 4673  JPMorgan Chase Bank            0          Market Place At Brick Branch
#
# ...

# %%
df = data.groupby(['City']).sum()

# %%
df.describe()
# Out:
#        Main Office  Branch Number       Zipcode     Latitude     Longitude  \
# count  1750.000000    1750.000000  1.750000e+03  1750.000000   1750.000000
# mean      0.000571   10111.291429  1.547675e+05   100.231930   -251.566281
# std       0.023905   23511.136579  4.138601e+05   255.984409    617.033719
# min       0.000000       5.000000  2.110000e+03     0.000000 -12408.185410
# 25%       0.000000    3625.500000  4.302500e+04    40.197817   -235.048850
# 50%       0.000000    5340.500000  8.350550e+04    42.887705   -119.651050
# 75%       0.000000    9528.000000  1.402012e+05    83.197675    -84.423277
# max       1.000000  452791.000000  1.001674e+07  6032.168810      0.000000
#
#        2010 Deposits  2011 Deposits  2012 Deposits  2013 Deposits  \
# count   1.750000e+03   1.750000e+03   1.750000e+03   1.750000e+03
# mean    7.126076e+05   8.383289e+05   9.366125e+05   1.030615e+06
# std     1.628417e+07   1.933398e+07   2.166436e+07   2.378523e+07
# ...

# %%
df[df['Count']==148]
# Out:
#                Main Office  Branch Number  Zipcode    Latitude    Longitude  \
# City
# New York City            0         368896  1485733  6032.16881 -10948.71182
#
#                2010 Deposits  2011 Deposits  2012 Deposits  2013 Deposits  \
# City
# New York City    230434060.0      295168225      332910577      358095460
#
#                2014 Deposits  2015 Deposits  2016 Deposits  Count
# City
# New York City      390782070      404650132      454306129    148

# %% [markdown]
# <h2>Where did Chase Bank customers deposit the most money last year?</h2>

# %% [markdown]
# <h4>JPMorgan Chase Bank Main Office</h4>

# %% [markdown]
# <h2>Which bank branch has seen the most growth in deposits? </h2>

# %% [markdown]
# <h4>Dequindre 18 Mile Rd Branch</h4>

# %% [markdown]
# <h2>What city has the most bank branches per capita? </h2>

# %% [markdown]
# <h4>New York City</h4>

# %% [markdown]
# <h2>How did the bank network of branch locations grow over the past century? </h2>

# %%
df_change
# Out:
#                                     2010 Deposits  2011 Deposits  \
# Branch Name
# 1 30 and Broadway Branch                      NaN       0.515973
# 112th & Broadway Branch                       NaN       0.375773
# 12 Mile-Country Club Drive Branch             NaN       0.107506
# 12335 Venice Blvd Branch                      NaN       0.119021
# 135th Street & Fifth Avenue Branch            NaN       0.043180
# ...                                           ...            ...
# Zandale Branch                                NaN       0.056484
# Zanesville Brandywine Branch                  NaN       0.086886
# Zanesville Downtown Branch                    NaN       0.237112
# Zeeb Road Banking Branch                      NaN       0.214488
# Zionsville Branch                             NaN       0.127656
#
#                                     2012 Deposits  2013 Deposits  \
# Branch Name
# 1 30 and Broadway Branch                 0.302408       0.317574
# ...
