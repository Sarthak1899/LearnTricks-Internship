# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\mahe\Desktop\Internship\Task 6\default of credit card clients.csv')

# %%
data.head(10)
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
# 5   6      50000    1          1         2   37      0      0      0      0
# 6   7     500000    1          1         2   29      0      0      0      0
# 7   8     100000    2          2         2   23      0     -1     -1      0
# 8   9     140000    2          3         1   28      0      0      2      0
# 9  10      20000    1          3         2   35     -2     -2     -2     -2
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# ...

# %%
data.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_1         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
data['BILL_AMT2']
# Out:
# 0          3102
# 1          1725
# 2         14027
# 3         48233
# 4          5670
#           ...
# 29995    192815
# 29996      1828
# 29997      3356
# 29998     78379
# 29999     48905
# Name: BILL_AMT2, Length: 30000, dtype: int64

# %%
data.apply(lambda x: sum(x.isnull()))
# Out:
# ID           0
# LIMIT_BAL    0
# SEX          0
# EDUCATION    0
# MARRIAGE     0
# AGE          0
# PAY_1        0
# PAY_2        0
# PAY_3        0
# PAY_4        0
# PAY_5        0
# PAY_6        0
# BILL_AMT1    0
# BILL_AMT2    0
# BILL_AMT3    0
# BILL_AMT4    0
# BILL_AMT5    0
# BILL_AMT6    0
# PAY_AMT1     0
# PAY_AMT2     0
# PAY_AMT3     0
# PAY_AMT4     0
# PAY_AMT5     0
# PAY_AMT6     0
# dpnm         0
# dtype: int64

# %%
data['PAY_1'].value_counts()
# Out:
#  0    14737
# -1     5686
#  1     3688
# -2     2759
#  2     2667
#  3      322
#  4       76
#  5       26
#  8       19
#  6       11
#  7        9
# Name: PAY_1, dtype: int64

# %%
df = data

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
df['amt_pending1']=df['BILL_AMT1']-df['PAY_AMT1']

# %%
df['amt_pending2']=df['BILL_AMT2']-df['PAY_AMT2']

# %%
df['amt_pending3']=df['BILL_AMT3']-df['PAY_AMT3']

# %%
df['amt_pending4']=df['BILL_AMT4']-df['PAY_AMT4']

# %%
df['amt_pending5']=df['BILL_AMT5']-df['PAY_AMT5']

# %%
df['amt_pending6']=df['BILL_AMT6']-df['PAY_AMT6']

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'dpnm',
#        'amt_pending1', 'amt_pending2', 'amt_pending3', 'amt_pending4',
#        'amt_pending5', 'amt_pending6'],
#       dtype='object')

# %%
df.drop(['BILL_AMT1', 'BILL_AMT2',
       'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
       'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6'],axis=1,inplace = True)

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
df['amt_pending_tot'] = df['amt_pending1']+df['amt_pending2']+df['amt_pending3']+df['amt_pending4']+df['amt_pending5']+df['amt_pending6']

# %%
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_1         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
def log_reg(x_train,y_train):
    classifier = LogisticRegression()
    classifier.fit(x_train,y_train)
    
    return classifier

# %%
def naive_bayes(x_train,y_train):
    classifier = GaussianNB()
    classifier.fit(x_train,y_train)
    
    return classifier

# %%
def k_nearest_neighbors(x_train,y_train):
    classifier = KNeighborsClassifier(n_neighbors=10)
    classifier.fit(x_train,y_train)
    
    return classifier

# %%
def svc(x_train,y_train):
    classifier = SVC(kernel = 'rbf', gamma = 'scale')
    classifier.fit(x_train,y_train)
    
    return classifier

# %%
def decision_tree(x_train,y_train):
    classifier = DecisionTreeClassifier(max_depth=8)
    classifier.fit(x_train,y_train)
    
    return classifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
from sklearn.preprocessing import scale
X = df.drop(['dpnm','ID'],axis = 1)
X =scale(X)
Y = df['dpnm']

x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2)

# %%
def build_and_train_classifier(x_train,y_train,classification_fn):
    model = classification_fn(x_train,y_train)
    y_pred = model.predict(x_test)
    
    train_score = model.score(x_train,y_train)
    test_score = accuracy = accuracy_score(y_test,y_pred)
    
    print("Training Score: ",train_score)
    print("Testing Score: ", test_score)

# %%
build_and_train_classifier(x_train,y_train,log_reg)
# Out:
# Training Score:  0.8102916666666666
# Testing Score:  0.8111666666666667

# %%
build_and_train_classifier(x_train,y_train,naive_bayes)
# Out:
# Training Score:  0.8000416666666667
# Testing Score:  0.8028333333333333

# %%
build_and_train_classifier(x_train,y_train,k_nearest_neighbors)
# Out:
# Training Score:  0.8245
# Testing Score:  0.8095

# %%
build_and_train_classifier(x_train,y_train,svc)
# Out:
# Training Score:  0.8246666666666667
# Testing Score:  0.8211666666666667

# %%
build_and_train_classifier(x_train,y_train,decision_tree)
# Out:
# Training Score:  0.832875
# Testing Score:  0.8148333333333333

# %%
from sklearn.preprocessing import scale
X = df.drop(['dpnm','ID','amt_pending1','amt_pending2','amt_pending3','amt_pending4','amt_pending5','amt_pending6'],axis = 1)
X =scale(X)
Y = df['dpnm']

x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2)

# %%
build_and_train_classifier(x_train,y_train,log_reg)
# Out:
# Training Score:  0.8111666666666667
# Testing Score:  0.8046666666666666

# %%
build_and_train_classifier(x_train,y_train,naive_bayes)
# Out:
# Training Score:  0.8021666666666667
# Testing Score:  0.7985

# %%
build_and_train_classifier(x_train,y_train,k_nearest_neighbors)
# Out:
# Training Score:  0.827625
# Testing Score:  0.8068333333333333

# %%
build_and_train_classifier(x_train,y_train,svc)
# Out:
# Training Score:  0.8279583333333334
# Testing Score:  0.8165

# %%
build_and_train_classifier(x_train,y_train,decision_tree)
# Out:
# Training Score:  0.8327083333333334
# Testing Score:  0.814

# %%
data
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
from sklearn.preprocessing import scale
X = data.drop(['dpnm','ID'],axis = 1)
X =scale(X)
Y = data['dpnm']

x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2)

# %%
build_and_train_classifier(x_train,y_train,log_reg)
# Out:
# Training Score:  0.8104166666666667
# Testing Score:  0.8076666666666666

# %%
build_and_train_classifier(x_train,y_train,naive_bayes)
# Out:
# Training Score:  0.799625
# Testing Score:  0.8055

# %%
build_and_train_classifier(x_train,y_train,k_nearest_neighbors)
# Out:
# Training Score:  0.8278333333333333
# Testing Score:  0.8076666666666666

# %%
build_and_train_classifier(x_train,y_train,svc)
# Out:
# Training Score:  0.8274166666666667
# Testing Score:  0.8175

# %%
build_and_train_classifier(x_train,y_train,decision_tree)
# Out:
# Training Score:  0.834625
# Testing Score:  0.8158333333333333

# %%
log_model = LogisticRegression()

# %%
log_model.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred_log = log_model.predict(x_test)

# %%
accuracy_score(y_test,y_pred_log)
# Out:
# 0.8076666666666666

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = {15,70}

plt.plot(y_pred_log,label = 'Predicted')
plt.plot(y_test.values,label = 'Actual')
plt.ylabel('Credit Default')

plt.legend()
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
y_pred_log_all = log_model.predict(X)

# %%
accuracy_score(Y,y_pred_log_all)
# Out:
# 0.8098666666666666

# %%
df2 = data

# %%
df2['Prediction'] = y_pred_log_all

# %%
df2
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
df2.to_csv(r'C:\Users\mahe\Desktop\Internship\Task 6\pred_with_log_model.csv',index= False)

# %%
dt_model=DecisionTreeClassifier(max_depth=8)

# %%
dt_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=8, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
y_pred_dt = dt_model.predict(x_test)

# %%
accuracy_score(y_test,y_pred_dt)
# Out:
# 0.8153333333333334

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = {15,70}

plt.plot(y_pred_dt,label = 'Predicted')
plt.plot(y_test.values,label = 'Actual')
plt.ylabel('Credit Default')

plt.legend()
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
y_pred_dt_all = dt_model.predict(X)

# %%
accuracy_score(Y,y_pred_dt_all)
# Out:
# 0.8307666666666667

# %%
data['Prediction'] = y_pred_dt_all

# %%
data
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
data.to_csv(r'C:\Users\mahe\Desktop\Internship\Task 6\pred_with_dt_model.csv',index= False)
