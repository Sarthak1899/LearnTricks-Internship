# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\mahe\Desktop\Task 2\Bank marketing.csv')

# %%
data.head(10)
# Out:
#    age          job  marital            education  default housing loan  \
# 0   56    housemaid  married             basic.4y       no      no   no
# 1   57     services  married          high.school  unknown      no   no
# 2   37     services  married          high.school       no     yes   no
# 3   40       admin.  married             basic.6y       no      no   no
# 4   56     services  married          high.school       no      no  yes
# 5   45     services  married             basic.9y  unknown      no   no
# 6   59       admin.  married  professional.course       no      no   no
# 7   41  blue-collar  married              unknown  unknown      no   no
# 8   24   technician   single  professional.course       no     yes   no
# 9   25     services   single          high.school       no     yes   no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  telephone   may         mon  ...         1    999         0  nonexistent
# ...

# %%
data['duration']
# Out:
# 0        261
# 1        149
# 2        226
# 3        151
# 4        307
#         ...
# 41183    334
# 41184    383
# 41185    189
# 41186    442
# 41187    239
# Name: duration, Length: 41188, dtype: int64

# %%
data[data['duration']==0]
# Out:
#        age          job   marital          education default housing loan  \
# 6251    39       admin.   married        high.school      no     yes   no
# 23031   59   management   married  university.degree      no     yes   no
# 28063   53  blue-collar  divorced        high.school      no     yes   no
# 33015   31  blue-collar   married           basic.9y      no      no   no
#
#          contact month day_of_week  ...  campaign  pdays  previous  \
# 6251   telephone   may         tue  ...         4    999         0
# 23031   cellular   aug         tue  ...        10    999         0
# 28063   cellular   apr         fri  ...         3    999         0
# 33015   cellular   may         mon  ...         2    999         0
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 6251   nonexistent          1.1          93.994          -36.4      4.857
# 23031  nonexistent          1.4          93.444          -36.1      4.965
# ...

# %%
data['job'].value_counts()
# Out:
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1720
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: job, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
data['marital'].value_counts()
# Out:
# married     24928
# single      11568
# divorced     4612
# unknown        80
# Name: marital, dtype: int64

# %%
data.apply(lambda x: sum(x.isnull()))
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
data['education'].value_counts()
# Out:
# university.degree      12168
# high.school             9515
# basic.9y                6045
# professional.course     5243
# basic.4y                4176
# basic.6y                2292
# unknown                 1731
# illiterate                18
# Name: education, dtype: int64

# %%
data['job'].value_counts()
# Out:
# admin.           10422
# blue-collar       9254
# technician        6743
# services          3969
# management        2924
# retired           1720
# entrepreneur      1456
# self-employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: job, dtype: int64

# %%
data
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
import numpy as np
data.replace({"unknown":np.nan},inplace = True)

# %%
data
# Out:
#        age          job  marital            education default housing loan  \
# 0       56    housemaid  married             basic.4y      no      no   no
# 1       57     services  married          high.school     NaN      no   no
# 2       37     services  married          high.school      no     yes   no
# 3       40       admin.  married             basic.6y      no      no   no
# 4       56     services  married          high.school      no      no  yes
# ...    ...          ...      ...                  ...     ...     ...  ...
# 41183   73      retired  married  professional.course      no     yes   no
# 41184   46  blue-collar  married  professional.course      no      no   no
# 41185   56      retired  married    university.degree      no     yes   no
# 41186   44   technician  married  professional.course      no      no   no
# 41187   74      retired  married  professional.course      no     yes   no
#
# ...

# %%
df = data.dropna(axis =0,how = 'any')

# %%
df
# Out:
#        age          job  marital            education default housing loan  \
# 0       56    housemaid  married             basic.4y      no      no   no
# 2       37     services  married          high.school      no     yes   no
# 3       40       admin.  married             basic.6y      no      no   no
# 4       56     services  married          high.school      no      no  yes
# 6       59       admin.  married  professional.course      no      no   no
# ...    ...          ...      ...                  ...     ...     ...  ...
# 41183   73      retired  married  professional.course      no     yes   no
# 41184   46  blue-collar  married  professional.course      no      no   no
# 41185   56      retired  married    university.degree      no     yes   no
# 41186   44   technician  married  professional.course      no      no   no
# 41187   74      retired  married  professional.course      no     yes   no
#
# ...

# %%
df['job'] = le.fit_transform(df['job'])
df['marital'] = le.fit_transform(df['marital'])
# Out:
# <ipython-input-93-701fb3dc077c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['job'] = le.fit_transform(df['job'])
# <ipython-input-93-701fb3dc077c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['marital'] = le.fit_transform(df['marital'])

# %%
df['education'] = le.fit_transform(df['education'])
df['default'] = le.fit_transform(df['default'])
df['housing'] = le.fit_transform(df['housing'])
df['loan'] = le.fit_transform(df['loan'])
df['contact'] = le.fit_transform(df['contact'])
df['month'] = le.fit_transform(df['month'])
df['day_of_week'] = le.fit_transform(df['day_of_week'])
# Out:
# <ipython-input-94-0af6e8dba978>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['education'] = le.fit_transform(df['education'])
# <ipython-input-94-0af6e8dba978>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['default'] = le.fit_transform(df['default'])
# <ipython-input-94-0af6e8dba978>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df['poutcome'].value_counts()
# Out:
# nonexistent    25836
# failure         3461
# success         1191
# Name: poutcome, dtype: int64

# %%
df['poutcome'] = le.fit_transform(df['poutcome'])
# Out:
# <ipython-input-96-3ff806e136be>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['poutcome'] = le.fit_transform(df['poutcome'])

# %%
df['pdays'].value_counts()
# Out:
# 999    29178
# 3        381
# 6        363
# 4        102
# 2         53
# 9         53
# 12        50
# 7         50
# 5         43
# 10        40
# 13        33
# 11        25
# 15        22
# 1         21
# 14        17
# 0         14
# 8         13
# 16         8
# 17         6
# 18         5
# 19         3
# 22         3
# 21         2
# 25         1
# 26         1
# 27         1
# Name: pdays, dtype: int64

# %%
from sklearn.preprocessing import Binarizer
bn = Binarizer(threshold=28)

bn_trans = bn.transform([df['pdays']])[0]
df['pdays'] = bn_trans
# Out:
# <ipython-input-98-1c1b6f04fc50>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pdays'] = bn_trans

# %%
df
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0       56    3        1          0        0        0     0        1      6
# 2       37    7        1          3        0        1     0        1      6
# 3       40    0        1          1        0        0     0        1      6
# 4       56    7        1          3        0        0     1        1      6
# 6       59    0        1          5        0        0     0        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41183   73    5        1          5        0        1     0        0      7
# 41184   46    1        1          5        0        0     0        0      7
# 41185   56    5        1          6        0        1     0        0      7
# 41186   44    9        1          5        0        0     0        0      7
# 41187   74    5        1          5        0        1     0        0      7
#
# ...

# %%
df.describe()
# Out:
#                 age           job       marital     education       default  \
# count  30488.000000  30488.000000  30488.000000  30488.000000  30488.000000
# mean      39.030012      3.716708      1.193191      3.842791      0.000098
# std       10.333529      3.612755      0.623663      1.988911      0.009919
# min       17.000000      0.000000      0.000000      0.000000      0.000000
# 25%       31.000000      0.000000      1.000000      2.000000      0.000000
# 50%       37.000000      2.000000      1.000000      3.000000      0.000000
# 75%       45.000000      7.000000      2.000000      6.000000      0.000000
# max       95.000000     10.000000      2.000000      6.000000      1.000000
#
#             housing          loan       contact         month   day_of_week  \
# count  30488.000000  30488.000000  30488.000000  30488.000000  30488.000000
# mean       0.541885      0.156389      0.329474      4.249442      2.015022
# ...

# %%
import seaborn as sns
sns.pairplot(df)

# %%
sns.heatmap(df.corr())

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
def naive_bayes(x_train,y_train):
    classifier = GaussianNB()
    classifier.fit(x_train,y_train)
    
    return classifier

# %%
def k_nearest_neighbors(x_train,y_train):
    classifier = KNeighborsClassifier(n_neighbors=10)
    classifier.fit(x_train,y_train)
    
    return classifier

# %%
def svc(x_train,y_train):
    classifier = SVC(kernel = 'rbf', gamma = 'scale')
    classifier.fit(x_train,y_train)
    
    return classifier

# %%
def decision_tree(x_train,y_train):
    classifier = DecisionTreeClassifier(max_depth=6)
    classifier.fit(x_train,y_train)
    
    return classifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
from sklearn.preprocessing import scale
X = df.drop(['y'],axis = 1)
X =scale(X)
Y = df['y']

x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2)

# %%
def build_and_train_classifier(x_train,y_train,classification_fn):
    model = classification_fn(x_train,y_train)
    y_pred = model.predict(x_test)
    
    train_score = model.score(x_train,y_train)
    test_score = accuracy = accuracy_score(y_test,y_pred)
    
    print("Training Score: ",train_score)
    print("Testing Score: ", test_score)

# %%
build_and_train_classifier(x_train,y_train,naive_bayes)
# Out:
# Training Score:  0.33091430914309145
# Testing Score:  0.31797310593637257

# %%
build_and_train_classifier(x_train,y_train,k_nearest_neighbors)
# Out:
# Training Score:  0.9040180401804018
# Testing Score:  0.8965234503115775

# %%
build_and_train_classifier(x_train,y_train,svc)
# Out:
# Training Score:  0.9104141041410414
# Testing Score:  0.9022630370613316

# %%
build_and_train_classifier(x_train,y_train,decision_tree)
# Out:
# Training Score:  0.9129151291512915
# Testing Score:  0.9011151197113808

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
logreg = LogisticRegression()
logreg.fit(x_train,y_train)
y_pred = logreg.predict(x_train)
print('Train accuracy score:',accuracy_score(y_train,y_pred))
print('Test accuracy score:', accuracy_score(y_test,logreg.predict(x_test)))
# Out:
# Train accuracy score: 0.8994669946699467
# Test accuracy score: 0.9012791079042309

# %%
kn_model = KNeighborsClassifier(n_neighbors=10)
kn_model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')

# %%
dt_model = DecisionTreeClassifier(max_depth=6)
dt_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=6, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
y_pred_kn = kn_model.predict(x_test)

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = {15,70}

plt.plot(y_pred_kn,label = 'Predicted')
plt.plot(y_test.values,label = 'Actual')
plt.ylabel('Term Deposit')

plt.legend()
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
y_pred_dt = dt_model.predict(x_test)

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = {15,70}

plt.plot(y_pred_dt,label = 'Predicted')
plt.plot(y_test.values,label = 'Actual')
plt.ylabel('Term Deposit')

plt.legend()
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
accuracy_score(y_test,y_pred_dt)
# Out:
# 0.9011151197113808

# %%
accuracy_score(y_test,y_pred_kn)
# Out:
# 0.8965234503115775

# %%
y_predall_dt = dt_model.predict(X)

# %%
accuracy_score(Y,y_predall_dt)
# Out:
# 0.9105549724481763

# %%
df['Prediction']= y_predall_dt
# Out:
# <ipython-input-129-6b60cce3d9e5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Prediction']= y_predall_dt

# %%
df
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0       56    3        1          0        0        0     0        1      6
# 2       37    7        1          3        0        1     0        1      6
# 3       40    0        1          1        0        0     0        1      6
# 4       56    7        1          3        0        0     1        1      6
# 6       59    0        1          5        0        0     0        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41183   73    5        1          5        0        1     0        0      7
# 41184   46    1        1          5        0        0     0        0      7
# 41185   56    5        1          6        0        1     0        0      7
# 41186   44    9        1          5        0        0     0        0      7
# 41187   74    5        1          5        0        1     0        0      7
#
# ...

# %%
df.to_csv(r'C:\Users\mahe\Desktop\Task 2\pred_without_nullvalues.csv',index= False)

# %%
data
# Out:
#        age          job  marital            education default housing loan  \
# 0       56    housemaid  married             basic.4y      no      no   no
# 1       57     services  married          high.school     NaN      no   no
# 2       37     services  married          high.school      no     yes   no
# 3       40       admin.  married             basic.6y      no      no   no
# 4       56     services  married          high.school      no      no  yes
# ...    ...          ...      ...                  ...     ...     ...  ...
# 41183   73      retired  married  professional.course      no     yes   no
# 41184   46  blue-collar  married  professional.course      no      no   no
# 41185   56      retired  married    university.degree      no     yes   no
# 41186   44   technician  married  professional.course      no      no   no
# 41187   74      retired  married  professional.course      no     yes   no
#
# ...

# %%
df = data.dropna(axis =0,how = 'any')
df['job'] = le.fit_transform(df['job'])
df['marital'] = le.fit_transform(df['marital'])
df['education'] = le.fit_transform(df['education'])
df['default'] = le.fit_transform(df['default'])
df['housing'] = le.fit_transform(df['housing'])
df['loan'] = le.fit_transform(df['loan'])
df['contact'] = le.fit_transform(df['contact'])
df['month'] = le.fit_transform(df['month'])
df['day_of_week'] = le.fit_transform(df['day_of_week'])
df['poutcome'] = le.fit_transform(df['poutcome'])
# Out:
# <ipython-input-134-fe7f62ab32d2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['job'] = le.fit_transform(df['job'])
# <ipython-input-134-fe7f62ab32d2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['marital'] = le.fit_transform(df['marital'])
# <ipython-input-134-fe7f62ab32d2>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
from sklearn.preprocessing import Binarizer
bn = Binarizer(threshold=28)

bn_trans = bn.transform([df['pdays']])[0]
df['pdays'] = bn_trans
# Out:
# <ipython-input-135-1c1b6f04fc50>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pdays'] = bn_trans

# %%
from sklearn.preprocessing import scale
X = df.drop(['y','duration'],axis = 1)
X =scale(X)
Y = df['y']

x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2)

# %%
build_and_train_classifier(x_train,y_train,naive_bayes)
# Out:
# Training Score:  0.24165641656416564
# Testing Score:  0.24024270252541818

# %%
build_and_train_classifier(x_train,y_train,k_nearest_neighbors)
# Out:
# Training Score:  0.8944649446494465
# Testing Score:  0.8847163004263693

# %%
build_and_train_classifier(x_train,y_train,svc)
# Out:
# Training Score:  0.893849938499385
# Testing Score:  0.8863561823548705

# %%
build_and_train_classifier(x_train,y_train,decision_tree)
# Out:
# Training Score:  0.894669946699467
# Testing Score:  0.887176123319121

# %%
dt_model.fit(x_train,y_train)
dt_model.score(x_train,y_train)
# Out:
# 0.894669946699467

# %%
y_pred_all_withoutduration = dt_model.predict(X)

# %%
accuracy_score(Y,y_pred_all_withoutduration)
# Out:
# 0.893138283914983

# %%
df['Prediction']= y_pred_all_withoutduration
# Out:
# <ipython-input-145-f6a42085eb28>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Prediction']= y_pred_all_withoutduration

# %%
df.to_csv(r'C:\Users\mahe\Desktop\Task 2\pred_without_nullvalues_without_duration.csv',index= False)

# %%
data
# Out:
#        age          job  marital            education default housing loan  \
# 0       56    housemaid  married             basic.4y      no      no   no
# 1       57     services  married          high.school     NaN      no   no
# 2       37     services  married          high.school      no     yes   no
# 3       40       admin.  married             basic.6y      no      no   no
# 4       56     services  married          high.school      no      no  yes
# ...    ...          ...      ...                  ...     ...     ...  ...
# 41183   73      retired  married  professional.course      no     yes   no
# 41184   46  blue-collar  married  professional.course      no      no   no
# 41185   56      retired  married    university.degree      no     yes   no
# 41186   44   technician  married  professional.course      no      no   no
# 41187   74      retired  married  professional.course      no     yes   no
#
# ...

# %%
mode_job = data['job'].mode()
mode_marital = data['marital'].mode()
mode_education = data['education'].mode()
mode_default = data['default'].mode()
mode_housing = data['housing'].mode()
mode_loan = data['loan'].mode()
mode_contact = data['contact'].mode()
mode_month = data['month'].mode()
mode_dayofweek = data['day_of_week'].mode()
mode_poutcome = data['poutcome'].mode()

# %%
data['job'].fillna(mode_job)
data['marital'].fillna(mode_marital)
data['education'].fillna(mode_education)
data['default'].fillna(mode_default)
data['housing'].fillna(mode_housing)
data['loan'].fillna(mode_loan)
data['contact'].fillna(mode_contact)
data['month'].fillna(mode_month)
data['day_of_week'].fillna(mode_dayofweek)
data['poutcome'].fillna(mode_poutcome)
# Out:
# 0        nonexistent
# 1        nonexistent
# 2        nonexistent
# 3        nonexistent
# 4        nonexistent
#             ...
# 41183    nonexistent
# 41184    nonexistent
# 41185    nonexistent
# 41186    nonexistent
# 41187        failure
# Name: poutcome, Length: 41188, dtype: object

# %%
data.apply(lambda x: sum(x.isnull()))
# Out:
# age                  0
# job                330
# marital             80
# education         1731
# default           8597
# housing            990
# loan               990
# contact              0
# month                0
# day_of_week          0
# duration             0
# campaign             0
# pdays                0
# previous             0
# poutcome             0
# emp.var.rate         0
# cons.price.idx       0
# cons.conf.idx        0
# euribor3m            0
# nr.employed          0
# y                    0
# dtype: int64

# %%
mode_job
# Out:
# 0    admin.
# dtype: object

# %%
data['job'].fillna('admin')
# Out:
# 0          housemaid
# 1           services
# 2           services
# 3             admin.
# 4           services
#             ...
# 41183        retired
# 41184    blue-collar
# 41185        retired
# 41186     technician
# 41187        retired
# Name: job, Length: 41188, dtype: object

# %%
mode_marital = data['marital'].mode()
data['marital'].fillna(mode_marital)
# Out:
# 0        married
# 1        married
# 2        married
# 3        married
# 4        married
#           ...
# 41183    married
# 41184    married
# 41185    married
# 41186    married
# 41187    married
# Name: marital, Length: 41188, dtype: object

# %%
mode_education = data['education'].mode()
data['education'].fillna(mode_education)
# Out:
# 0                   basic.4y
# 1                high.school
# 2                high.school
# 3                   basic.6y
# 4                high.school
#                 ...
# 41183    professional.course
# 41184    professional.course
# 41185      university.degree
# 41186    professional.course
# 41187    professional.course
# Name: education, Length: 41188, dtype: object

# %%
mode_default = data['default'].mode()
data['default'].fillna(mode_default,inplace=True)

# %%
data.apply(lambda x: sum(x.isnull()))
# Out:
# age                  0
# job                330
# marital             80
# education         1731
# default           8597
# housing            990
# loan               990
# contact              0
# month                0
# day_of_week          0
# duration             0
# campaign             0
# pdays                0
# previous             0
# poutcome             0
# emp.var.rate         0
# cons.price.idx       0
# cons.conf.idx        0
# euribor3m            0
# nr.employed          0
# y                    0
# dtype: int64

# %%
for column in ['job', 'marital', 'education', 'default', 'housing','loan']:
    data[column].fillna(data[column].mode()[0], inplace=True)

# %%
data.apply(lambda x: sum(x.isnull()))
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
data['job'] = le.fit_transform(data['job'])
data['marital'] = le.fit_transform(data['marital'])
data['education'] = le.fit_transform(data['education'])
data['default'] = le.fit_transform(data['default'])
data['housing'] = le.fit_transform(data['housing'])
data['loan'] = le.fit_transform(data['loan'])
data['contact'] = le.fit_transform(data['contact'])
data['month'] = le.fit_transform(data['month'])
data['day_of_week'] = le.fit_transform(data['day_of_week'])
data['poutcome'] = le.fit_transform(data['poutcome'])

# %%
data
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0       56    3        1          0        0        0     0        1      6
# 1       57    7        1          3        0        0     0        1      6
# 2       37    7        1          3        0        1     0        1      6
# 3       40    0        1          1        0        0     0        1      6
# 4       56    7        1          3        0        0     1        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41183   73    5        1          5        0        1     0        0      7
# 41184   46    1        1          5        0        0     0        0      7
# 41185   56    5        1          6        0        1     0        0      7
# 41186   44    9        1          5        0        0     0        0      7
# 41187   74    5        1          5        0        1     0        0      7
#
# ...

# %%
bn = Binarizer(threshold=28)

bn_trans = bn.transform([data['pdays']])[0]
data['pdays'] = bn_trans

# %%
X = data.drop(['y'],axis = 1)
X =scale(X)
Y = data['y']

x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2)

# %%
build_and_train_classifier(x_train,y_train,naive_bayes)
# Out:
# Training Score:  0.3439453717754173
# Testing Score:  0.3465647001699442

# %%
build_and_train_classifier(x_train,y_train,k_nearest_neighbors)
# Out:
# Training Score:  0.9144157814871017
# Testing Score:  0.9024034959941734

# %%
build_and_train_classifier(x_train,y_train,svc)
# Out:
# Training Score:  0.919453717754173
# Testing Score:  0.9092012624423403

# %%
build_and_train_classifier(x_train,y_train,decision_tree)
# Out:
# Training Score:  0.922701062215478
# Testing Score:  0.9106579266812334

# %%
dt_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=6, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
y_pred_all_imputted = dt_model.predict(X)

# %%
accuracy_score(Y,y_pred_all_imputted)
# Out:
# 0.9202923181509177

# %%
data['Prediction'] = y_pred_all_imputted

# %%
data
# Out:
#        age  job  marital  education  default  housing  loan  contact  month  \
# 0       56    3        1          0        0        0     0        1      6
# 1       57    7        1          3        0        0     0        1      6
# 2       37    7        1          3        0        1     0        1      6
# 3       40    0        1          1        0        0     0        1      6
# 4       56    7        1          3        0        0     1        1      6
# ...    ...  ...      ...        ...      ...      ...   ...      ...    ...
# 41183   73    5        1          5        0        1     0        0      7
# 41184   46    1        1          5        0        0     0        0      7
# 41185   56    5        1          6        0        1     0        0      7
# 41186   44    9        1          5        0        0     0        0      7
# 41187   74    5        1          5        0        1     0        0      7
#
# ...

# %%
data.to_csv(r'C:\Users\mahe\Desktop\Task 2\pred_with_imputedvalues.csv',index= False)
